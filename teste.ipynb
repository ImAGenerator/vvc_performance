# %%
import vvcpy as vp
file = 'teste_log.vvclog'

out = vp.prof.VVC_Output()

index = ['max', 'min', 'avg']
regex = r'max=(\d+\.\d+), min=(\d+\.\d+), avg=(\d+\.\d+)'

out.include_regex(regex, index)
out.read_file(file,27,True)
# Out:
# /home/luismendes/.local/lib/python3.10/site-packages/vvcpy/src/prof/vvc_output.py:31: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self.__regex_index__ = index
#    frame  t_frame  qp_offset  bitrate   Y_PSNR   U_PSNR   V_PSNR  YUV_PSNR  \
# 0      0  I-SLICE       -1.0  68040.0  40.8799  43.2898  43.4556   40.8799
# 0      1  B-SLICE        7.0   3056.0  38.8940  42.8809  42.5480   38.8940
# 0      2  B-SLICE        6.0   4944.0  38.7116  42.6221  41.7851   38.7116
# 0      3  B-SLICE        7.0   3792.0  38.0095  42.3521  41.3085   38.0095
# 0      4  B-SLICE        6.0   4960.0  38.1460  42.3715  41.1400   38.1460
# 0      5  B-SLICE        7.0   3368.0  37.7198  42.0496  40.7823   37.7198
# 0      6  B-SLICE        6.0   5720.0  38.0320  42.0873  41.1762   38.0320
# 0      7  B-SLICE        7.0   3896.0  37.6068  41.8015  40.7523   37.6068
# ...
